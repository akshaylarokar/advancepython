# %% [markdown]
# # function advance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("my name is akshay")
# Out:
# my name is akshay

# %%
def mul(x: float|int, y: float|int) -> float|int:
    """
    this funsion provides multipcation of two number
    """
    assert isinstance(x, (int, float)), "Expected x to be integer or float"
    assert isinstance(y,(int, float)), "Expected y to be integer or float"
    z = x*y
    return z

# %%
help(mul)
# Out:
# Help on function mul in module __main__:
#
# mul(x: float | int, y: float | int) -> float | int
#     this funsion provides multipcation of two number

# %%
mul(10,26)
# Out:
# 260

# %%
mul(85,25)
# Out:
# 2125

# %% [markdown]
# Arguments in python

# %%
def function(*args):
    print(f"Arguments : {args}")
    print(f"Type : {type(args)}")
    for i in args:
        print(i)

# %%
function("akki",25)
# Out:
# Arguments : ('akki', 25)
# Type : <class 'tuple'>
# akki
# 25

# %%
function("adv python", True, 34, 23.5,[1,2,3])
# Out:
# Arguments : ('adv python', True, 34, 23.5, [1, 2, 3])
# Type : <class 'tuple'>
# adv python
# True
# 34
# 23.5
# [1, 2, 3]

# %% [markdown]
# Upacking a list as argument in python

# %%
a = [12, "raman", True,13.5]
type(a)
# Out:
# list

# %%
function(*a)
# Out:
# Arguments : (12, 'raman', True, 13.5)
# Type : <class 'tuple'>
# 12
# raman
# True
# 13.5
